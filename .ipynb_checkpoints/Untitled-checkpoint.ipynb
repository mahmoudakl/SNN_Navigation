# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import Image, SVG

# %matplotlib inline
plt.rcParams['figure.figsize'] = (12, 6)

# %%
import nest
import nest.voltage_trace
import nest.raster_plot

# %%
import evolution as ev
import environment as env
import network
import results
import time

# %%
i = 30
path = '../Results/actual results/arena1/population2/mat2/fixed/population1/'
individual = np.load(path+'gen{}/best_individual.npy'.format(i))
results.draw_network(individual)

# %%
nest.ResetKernel()
nest.SetKernelStatus({'resolution': 1.0, 'local_num_threads': 4})
ev.create_network(individual)
x = 100
y = 200
theta = 0

# %%
current_pose = (x, y, theta)
for t in range(400):
